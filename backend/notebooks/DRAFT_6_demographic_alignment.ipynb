# %% [markdown]
# # 6. Demographic Alignment Analysis
#
# **Goal**: Measure which demographic groups (gender, income, social class) are most/least aligned with how the EU Parliament actually voted.
#
# **Method**:
# 1. Join `survey_answer_alignments` (Supabase) with `volume_b_answer_distributions.csv` on `(question_id, file_name, answer_label)`
# 2. Compute per-question alignment scores by demographic group
# 3. Aggregate across all questions
# 4. Statistical tests (chi-squared, Cramer's V, pairwise z-tests)

# %%
import os
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
from scipy.stats import chi2_contingency
from supabase import create_client

warnings.filterwarnings("ignore", category=FutureWarning)
sns.set_theme(style="whitegrid", palette="muted")

load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
print("Supabase connected.")
# Out:
# Supabase connected.

# %% [markdown]
# ## 2. Load alignments from Supabase

# %%
# Load survey_answer_alignments
alignments_resp = supabase.table("survey_answer_alignments").select("*").execute()
df_alignments = pd.DataFrame(alignments_resp.data)
print(f"Alignments loaded: {len(df_alignments)} rows")
print(f"Columns: {list(df_alignments.columns)}")
display(df_alignments.head())

# Load survey_vote_matches for context (question text, vote info)
matches_resp = (
    supabase.table("survey_vote_matches")
    .select(
        "match_id, question_id, question_clean, survey_file, vote_id, vote_summary_clean, vote_date"
    )
    .eq("admin_validated", True)
    .execute()
)
df_matches = pd.DataFrame(matches_resp.data)
print(f"\nAccepted matches loaded: {len(df_matches)} rows")
display(df_matches.head())
# Out:
# Alignments loaded: 774 rows
# Columns: ['match_id', 'answer_label', 'alignment', 'survey_file', 'question_id', 'vote_id', 'created_at']
#         match_id                            answer_label  alignment  \
# 0   T13_153304_0  More decision-making at European level    aligned
# 1   T13_153304_0  Less decision-making at European level    opposed
# 2   T13_153304_0        No change is needed/as it is now    neutral
# 3   T13_153304_0                              Don't know    unknown
# 4  QA23_154611_1             Les fruits et légumes frais  unrelated
#
#                                   survey_file question_id  vote_id  \
# 0                       ebs_509_volume_B.xlsx         T13   153304
# 1                       ebs_509_volume_B.xlsx         T13   153304
# 2                       ebs_509_volume_B.xlsx         T13   153304
# 3                       ebs_509_volume_B.xlsx         T13   153304
# 4  Lien_vers_CAP_2022_eb_sp_520_volume_B.xlsx        QA23   154611
#
#                          created_at
# 0  2026-03-15T08:19:32.290181+00:00
# 1  2026-03-15T08:19:32.290181+00:00
# 2  2026-03-15T08:19:32.290181+00:00
# 3  2026-03-15T08:19:32.290181+00:00
# 4   2026-03-15T08:23:24.91182+00:00
# Accepted matches loaded: 97 rows
#          match_id question_id  \
# 0  QE3_9_157788_4       QE3_9
# 1    T13_153304_0         T13
# 2    T68_157227_7         T68
# 3    T13_148875_9         T13
# 4     T7_164961_6          T7
#
#                                       question_clean  \
# 0  To what extent do you agree or disagree that t...
# 1  Should more or less decision-making for protec...
# 2  To what extent do you agree that the EU should...
# 3  Should more or less decision-making for protec...
# 4  Do you agree or disagree that the EU should st...
#
#                     survey_file  vote_id  \
# 0  Lien_vers_eb98_volume_B.xlsx   157788
# 1         ebs_509_volume_B.xlsx   153304
# 2         ebs_500_volume_B.xlsx   157227
# 3         ebs_509_volume_B.xlsx   148875
# 4         ebs_512_volume_B.xlsx   164961
#
#                                   vote_summary_clean            vote_date
# 0  The European Parliament voted to increase rene...  2023-09-12 12:16:00
# 1  The European Parliament voted to approve a pla...  2023-03-14 12:15:00
# 2  Parliament approved recommendations to enhance...  2023-07-12 13:20:00
# 3  The European Parliament, in a vote of 468 to 5...  2022-10-06 12:23:00
# 4  The European Parliament approved, by a signifi...  2024-02-29 12:04:00

# %%
df_all_votes = pd.read_csv(
    "/Users/ugo/Documents/MH2D_projets/dawta/eu_survey_correlation/data/votes/votes.csv"
)

# %%
df_all_votes["vote_accepted"] = (
    df_all_votes["count_for"] > df_all_votes["count_against"]
)
df_matches = df_matches.merge(
    df_all_votes[["id", "vote_accepted"]], left_on="vote_id", right_on="id"
)

# %%
df_matches.vote_accepted.value_counts()
# Out:
# vote_accepted
# True    97
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Load & filter CSV distributions

# %%
CSV_PATH = "./data/surveys/volume_b_answer_distributions.csv"
df_csv = pd.read_csv(CSV_PATH)
print(f"CSV loaded: {len(df_csv)} rows")
print(f"Columns: {list(df_csv.columns)}")
print(f"\nDemographic types: {df_csv['demographic_type'].unique()}")
print(f"is_summary values: {df_csv['is_summary'].unique()}")

# Filter: non-summary, target demographics only
TARGET_DEMOGRAPHICS = ["gender", "income_difficulty", "class_belonging"]
df_demo = df_csv[
    (df_csv["is_summary"] == False)
    & (df_csv["demographic_type"].isin(TARGET_DEMOGRAPHICS))
].copy()
print(f"\nFiltered to target demographics: {len(df_demo)} rows")
print(f"Demographic breakdown:")
for dt in TARGET_DEMOGRAPHICS:
    subset = df_demo[df_demo["demographic_type"] == dt]
    print(
        f"  {dt}: {len(subset)} rows, values: {sorted(subset['demographic_value'].unique())}"
    )
# Out:
# CSV loaded: 16460 rows
# Columns: ['sheet_id', 'file_name', 'question_clean', 'answer_label', 'is_summary', 'demographic_type', 'demographic_value', 'count', 'pct', 'total_base']
#
# Demographic types: <ArrowStringArray>
# ['total', 'gender', 'income_difficulty', 'occupation', 'class_belonging']
# Length: 5, dtype: str
# is_summary values: [False  True]
#
# Filtered to target demographics: 6662 rows
# Demographic breakdown:
#   gender: 1666 rows, values: ['female', 'male']
#   income_difficulty: 1911 rows, values: ['medium', 'poor', 'rich']
#   class_belonging: 3085 rows, values: ['lower_middle', 'middle', 'upper', 'upper_middle', 'working_class']

# %%
df_demo
# Out:
#       sheet_id                                          file_name  \
# 1        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 2        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 3        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 4        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 5        QA1_2  Fairness_perception_green_transition_2022_ebs_...
# ...        ...                                                ...
# 16427     Q6_7                               fl_506_volume_B.xlsx
# 16433     Q6_7                               fl_506_volume_B.xlsx
# 16434     Q6_7                               fl_506_volume_B.xlsx
# 16440     Q6_7                               fl_506_volume_B.xlsx
# 16441     Q6_7                               fl_506_volume_B.xlsx
#
#                                           question_clean  \
# 1      Do you agree or disagree that the green transi...
# 2      Do you agree or disagree that the green transi...
# 3      Do you agree or disagree that the green transi...
# 4      Do you agree or disagree that the green transi...
# 5      Do you agree or disagree that the green transi...
# ...                                                  ...
# 16427  Do you agree or disagree that EU Member States...
# 16433  Do you agree or disagree that EU Member States...
# 16434  Do you agree or disagree that EU Member States...
# 16440  Do you agree or disagree that EU Member States...
# 16441  Do you agree or disagree that EU Member States...
#
#                answer_label  is_summary   demographic_type demographic_value  \
# 1      Tout à fait d'accord       False             gender              male
# 2      Tout à fait d'accord       False             gender            female
# 3      Tout à fait d'accord       False  income_difficulty              poor
# 4      Tout à fait d'accord       False  income_difficulty            medium
# 5      Tout à fait d'accord       False  income_difficulty              rich
# ...                     ...         ...                ...               ...
# 16427      Tend to disagree       False             gender            female
# 16433      Totally disagree       False             gender              male
# 16434      Totally disagree       False             gender            female
# 16440            Don’t know       False             gender              male
# 16441            Don’t know       False             gender            female
#
#         count   pct  total_base
# 1      6198.0  49.0     12635.0
# 2      7018.0  51.0     13739.0
# 3      1029.0  49.0      2104.0
# 4      3029.0  44.0      6959.0
# 5      9027.0  53.0     17085.0
# ...       ...   ...         ...
# 16427   714.0   5.3     13442.0
# 16433   509.0   4.1     12547.0
# 16434   394.0   2.9     13442.0
# 16440   512.0   4.1     12547.0
# 16441  1086.0   8.1     13442.0
#
# [6662 rows x 10 columns]

# %% [markdown]
# ## 4. Join datasets

# %%
# Normalize join keys
df_alignments["question_id"] = df_alignments["question_id"].astype(str).str.strip()
df_alignments["survey_file"] = df_alignments["survey_file"].astype(str).str.strip()
df_alignments["answer_label"] = df_alignments["answer_label"].astype(str).str.strip()

df_demo["sheet_id"] = df_demo["sheet_id"].astype(str).str.strip()
df_demo["file_name"] = df_demo["file_name"].astype(str).str.strip()
df_demo["answer_label"] = df_demo["answer_label"].astype(str).str.strip()

# Join: alignments <-> demographic distributions
df_joined = df_demo.merge(
    df_alignments[
        ["question_id", "survey_file", "answer_label", "alignment", "match_id"]
    ],
    left_on=["sheet_id", "file_name", "answer_label"],
    right_on=["question_id", "survey_file", "answer_label"],
    how="inner",
)

print(f"Joined rows: {len(df_joined)}")
print(f"Unique questions in join: {df_joined['question_id'].nunique()}")
print(f"Unique match_ids in join: {df_joined['match_id'].nunique()}")
print(f"Alignment distribution in join:")
print(df_joined["alignment"].value_counts())

if len(df_joined) == 0:
    print("\n⚠️ WARNING: Empty join! Check key normalization.")
    # Debug: show sample keys from each side
    print("\nAlignment keys (first 5):")
    print(df_alignments[["question_id", "survey_file", "answer_label"]].head())
    print("\nCSV keys (first 5):")
    print(df_demo[["sheet_id", "file_name", "answer_label"]].head())
else:
    display(df_joined.head())
# Out:
# Joined rows: 6853
# Unique questions in join: 44
# Unique match_ids in join: 96
# Alignment distribution in join:
# alignment
# unrelated    3837
# aligned      1196
# opposed      1084
# unknown       576
# neutral       160
# Name: count, dtype: int64
#   sheet_id                                          file_name  \
# 0    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 1    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 2    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 3    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 4    QA1_2  Fairness_perception_green_transition_2022_ebs_...
#
#                                       question_clean          answer_label  \
# 0  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 1  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 2  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 3  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 4  Do you agree or disagree that the green transi...  Tout à fait d'accord
#
#    is_summary   demographic_type demographic_value   count   pct  total_base  \
# 0       False             gender              male  6198.0  49.0     12635.0
# 1       False             gender              male  6198.0  49.0     12635.0
# 2       False             gender            female  7018.0  51.0     13739.0
# 3       False             gender            female  7018.0  51.0     13739.0
# 4       False  income_difficulty              poor  1029.0  49.0      2104.0
#
#   question_id                                        survey_file alignment  \
# 0       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 1       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 2       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 3       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 4       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
#
#            match_id
# 0  QA1_2_162155_411
# 1  QA1_2_160076_398
# 2  QA1_2_162155_411
# 3  QA1_2_160076_398
# 4  QA1_2_162155_411

# %%
df_joined.head()
# Out:
#   sheet_id                                          file_name  \
# 0    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 1    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 2    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 3    QA1_2  Fairness_perception_green_transition_2022_ebs_...
# 4    QA1_2  Fairness_perception_green_transition_2022_ebs_...
#
#                                       question_clean          answer_label  \
# 0  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 1  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 2  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 3  Do you agree or disagree that the green transi...  Tout à fait d'accord
# 4  Do you agree or disagree that the green transi...  Tout à fait d'accord
#
#    is_summary   demographic_type demographic_value   count   pct  total_base  \
# 0       False             gender              male  6198.0  49.0     12635.0
# 1       False             gender              male  6198.0  49.0     12635.0
# 2       False             gender            female  7018.0  51.0     13739.0
# 3       False             gender            female  7018.0  51.0     13739.0
# 4       False  income_difficulty              poor  1029.0  49.0      2104.0
#
#   question_id                                        survey_file alignment  \
# 0       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 1       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 2       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 3       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
# 4       QA1_2  Fairness_perception_green_transition_2022_ebs_...   aligned
#
#            match_id
# 0  QA1_2_162155_411
# 1  QA1_2_160076_398
# 2  QA1_2_162155_411
# 3  QA1_2_160076_398
# 4  QA1_2_162155_411

# %%
df_joined[
    (df_joined["file_name"] == "fl_506_volume_B.xlsx")
    & (df_joined["sheet_id"] == "Q6_4")
]
# Out:
#      sheet_id             file_name  \
# 6813     Q6_4  fl_506_volume_B.xlsx
# 6814     Q6_4  fl_506_volume_B.xlsx
# 6815     Q6_4  fl_506_volume_B.xlsx
# 6816     Q6_4  fl_506_volume_B.xlsx
# 6817     Q6_4  fl_506_volume_B.xlsx
# 6818     Q6_4  fl_506_volume_B.xlsx
# 6819     Q6_4  fl_506_volume_B.xlsx
# 6820     Q6_4  fl_506_volume_B.xlsx
# 6821     Q6_4  fl_506_volume_B.xlsx
# 6822     Q6_4  fl_506_volume_B.xlsx
# 6823     Q6_4  fl_506_volume_B.xlsx
# 6824     Q6_4  fl_506_volume_B.xlsx
# 6825     Q6_4  fl_506_volume_B.xlsx
# 6826     Q6_4  fl_506_volume_B.xlsx
# 6827     Q6_4  fl_506_volume_B.xlsx
# 6828     Q6_4  fl_506_volume_B.xlsx
# 6829     Q6_4  fl_506_volume_B.xlsx
# 6830     Q6_4  fl_506_volume_B.xlsx
# 6831     Q6_4  fl_506_volume_B.xlsx
# 6832     Q6_4  fl_506_volume_B.xlsx
#
#                                          question_clean      answer_label  \
# 6813  Agree or disagree: Should measures be taken at...     Totally agree
# 6814  Agree or disagree: Should measures be taken at...     Totally agree
# 6815  Agree or disagree: Should measures be taken at...     Totally agree
# 6816  Agree or disagree: Should measures be taken at...     Totally agree
# 6817  Agree or disagree: Should measures be taken at...     Tend to agree
# 6818  Agree or disagree: Should measures be taken at...     Tend to agree
# 6819  Agree or disagree: Should measures be taken at...     Tend to agree
# 6820  Agree or disagree: Should measures be taken at...     Tend to agree
# 6821  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6822  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6823  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6824  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6825  Agree or disagree: Should measures be taken at...  Totally disagree
# 6826  Agree or disagree: Should measures be taken at...  Totally disagree
# 6827  Agree or disagree: Should measures be taken at...  Totally disagree
# 6828  Agree or disagree: Should measures be taken at...  Totally disagree
# 6829  Agree or disagree: Should measures be taken at...        Don’t know
# 6830  Agree or disagree: Should measures be taken at...        Don’t know
# 6831  Agree or disagree: Should measures be taken at...        Don’t know
# 6832  Agree or disagree: Should measures be taken at...        Don’t know
#
#       is_summary demographic_type demographic_value   count   pct  total_base  \
# 6813       False           gender              male  6987.0  55.7     12547.0
# 6814       False           gender              male  6987.0  55.7     12547.0
# 6815       False           gender            female  7335.0  54.6     13442.0
# 6816       False           gender            female  7335.0  54.6     13442.0
# 6817       False           gender              male  4254.0  33.9     12547.0
# 6818       False           gender              male  4254.0  33.9     12547.0
# 6819       False           gender            female  4830.0  35.9     13442.0
# 6820       False           gender            female  4830.0  35.9     13442.0
# 6821       False           gender              male   744.0   5.9     12547.0
# 6822       False           gender              male   744.0   5.9     12547.0
# 6823       False           gender            female   446.0   3.3     13442.0
# 6824       False           gender            female   446.0   3.3     13442.0
# 6825       False           gender              male   294.0   2.3     12547.0
# 6826       False           gender              male   294.0   2.3     12547.0
# 6827       False           gender            female   198.0   1.5     13442.0
# 6828       False           gender            female   198.0   1.5     13442.0
# 6829       False           gender              male   268.0   2.1     12547.0
# 6830       False           gender              male   268.0   2.1     12547.0
# 6831       False           gender            female   632.0   4.7     13442.0
# 6832       False           gender            female   632.0   4.7     13442.0
#
#      question_id           survey_file  alignment        match_id
# 6813        Q6_4  fl_506_volume_B.xlsx    aligned  Q6_4_147557_86
# 6814        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6815        Q6_4  fl_506_volume_B.xlsx    aligned  Q6_4_147557_86
# 6816        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6817        Q6_4  fl_506_volume_B.xlsx    aligned  Q6_4_147557_86
# 6818        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6819        Q6_4  fl_506_volume_B.xlsx    aligned  Q6_4_147557_86
# 6820        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6821        Q6_4  fl_506_volume_B.xlsx    opposed  Q6_4_147557_86
# 6822        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6823        Q6_4  fl_506_volume_B.xlsx    opposed  Q6_4_147557_86
# 6824        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6825        Q6_4  fl_506_volume_B.xlsx    opposed  Q6_4_147557_86
# 6826        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6827        Q6_4  fl_506_volume_B.xlsx    opposed  Q6_4_147557_86
# 6828        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6829        Q6_4  fl_506_volume_B.xlsx    unknown  Q6_4_147557_86
# 6830        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52
# 6831        Q6_4  fl_506_volume_B.xlsx    unknown  Q6_4_147557_86
# 6832        Q6_4  fl_506_volume_B.xlsx  unrelated  Q6_4_147705_52

# %%
df_joined[df_joined["match_id"] == "Q6_4_147557_86"]
# Out:
#      sheet_id             file_name  \
# 6813     Q6_4  fl_506_volume_B.xlsx
# 6815     Q6_4  fl_506_volume_B.xlsx
# 6817     Q6_4  fl_506_volume_B.xlsx
# 6819     Q6_4  fl_506_volume_B.xlsx
# 6821     Q6_4  fl_506_volume_B.xlsx
# 6823     Q6_4  fl_506_volume_B.xlsx
# 6825     Q6_4  fl_506_volume_B.xlsx
# 6827     Q6_4  fl_506_volume_B.xlsx
# 6829     Q6_4  fl_506_volume_B.xlsx
# 6831     Q6_4  fl_506_volume_B.xlsx
#
#                                          question_clean      answer_label  \
# 6813  Agree or disagree: Should measures be taken at...     Totally agree
# 6815  Agree or disagree: Should measures be taken at...     Totally agree
# 6817  Agree or disagree: Should measures be taken at...     Tend to agree
# 6819  Agree or disagree: Should measures be taken at...     Tend to agree
# 6821  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6823  Agree or disagree: Should measures be taken at...  Tend to disagree
# 6825  Agree or disagree: Should measures be taken at...  Totally disagree
# 6827  Agree or disagree: Should measures be taken at...  Totally disagree
# 6829  Agree or disagree: Should measures be taken at...        Don’t know
# 6831  Agree or disagree: Should measures be taken at...        Don’t know
#
#       is_summary demographic_type demographic_value   count   pct  total_base  \
# 6813       False           gender              male  6987.0  55.7     12547.0
# 6815       False           gender            female  7335.0  54.6     13442.0
# 6817       False           gender              male  4254.0  33.9     12547.0
# 6819       False           gender            female  4830.0  35.9     13442.0
# 6821       False           gender              male   744.0   5.9     12547.0
# 6823       False           gender            female   446.0   3.3     13442.0
# 6825       False           gender              male   294.0   2.3     12547.0
# 6827       False           gender            female   198.0   1.5     13442.0
# 6829       False           gender              male   268.0   2.1     12547.0
# 6831       False           gender            female   632.0   4.7     13442.0
#
#      question_id           survey_file alignment        match_id
# 6813        Q6_4  fl_506_volume_B.xlsx   aligned  Q6_4_147557_86
# 6815        Q6_4  fl_506_volume_B.xlsx   aligned  Q6_4_147557_86
# 6817        Q6_4  fl_506_volume_B.xlsx   aligned  Q6_4_147557_86
# 6819        Q6_4  fl_506_volume_B.xlsx   aligned  Q6_4_147557_86
# 6821        Q6_4  fl_506_volume_B.xlsx   opposed  Q6_4_147557_86
# 6823        Q6_4  fl_506_volume_B.xlsx   opposed  Q6_4_147557_86
# 6825        Q6_4  fl_506_volume_B.xlsx   opposed  Q6_4_147557_86
# 6827        Q6_4  fl_506_volume_B.xlsx   opposed  Q6_4_147557_86
# 6829        Q6_4  fl_506_volume_B.xlsx   unknown  Q6_4_147557_86
# 6831        Q6_4  fl_506_volume_B.xlsx   unknown  Q6_4_147557_86

# %% [markdown]
# ## 5. Compute per-question alignment scores by demographic group

# %%
df_joined["count"].isna().sum()
# Out:
# np.int64(25)

# %%
# Ensure count is numeric
df_joined["count"] = pd.to_numeric(df_joined["count"], errors="coerce").fillna(0)
df_joined["total_base"] = pd.to_numeric(
    df_joined["total_base"], errors="coerce"
).fillna(0)

# Pivot: sum counts by alignment category per (question, demographic_type, demographic_value)
group_cols = ["question_id", "match_id", "demographic_type", "demographic_value"]

# Sum count per alignment category
pivot = (
    df_joined.groupby(group_cols + ["alignment"])["count"]
    .sum()
    .unstack(fill_value=0)
    .reset_index()
)

# Ensure alignment columns exist
for col in ["aligned", "opposed", "neutral"]:
    if col not in pivot.columns:
        pivot[col] = 0

# Compute alignment metrics
pivot["count_aligned"] = pivot["aligned"]
pivot["count_opposed"] = pivot["opposed"]
pivot["count_neutral"] = (
    pivot.get("neutral", 0) + pivot.get("unknown", 0) + pivot.get("unrelated", 0)
)
pivot["total"] = (
    pivot["count_aligned"] + pivot["count_opposed"] + pivot["count_neutral"]
)

# alignment_rate = aligned / (aligned + opposed), where denominator > 0
denom = pivot["count_aligned"] + pivot["count_opposed"]
pivot["alignment_rate"] = np.where(denom > 0, pivot["count_aligned"] / denom, np.nan)

# net_alignment_score = (aligned - opposed) / total
pivot["net_alignment_score"] = np.where(
    pivot["total"] > 0,
    (pivot["count_aligned"] - pivot["count_opposed"]) / pivot["total"],
    np.nan,
)

print(f"Per-question scores computed: {len(pivot)} rows")
display(pivot.head(10))
# Out:
# Per-question scores computed: 755 rows
# alignment question_id         match_id demographic_type demographic_value  \
# 0               Q10_2  Q10_2_171271_11           gender            female
# 1               Q10_2  Q10_2_171271_11           gender              male
# 2               Q10_3  Q10_3_171271_20           gender            female
# 3               Q10_3  Q10_3_171271_20           gender              male
# 4                 Q12    Q12_147522_33           gender            female
# 5                 Q12    Q12_147522_33           gender              male
# 6                 Q12   Q12_160063_196           gender            female
# 7                 Q12   Q12_160063_196           gender              male
# 8                Q2_2  Q2_2_181339_414           gender            female
# 9                Q2_2  Q2_2_181339_414           gender              male
#
# alignment  aligned  neutral  opposed  unknown  unrelated  count_aligned  \
# 0          10657.0      0.0   2162.0    358.0        0.0        10657.0
# 1          10204.0      0.0   1996.0    220.0        0.0        10204.0
# 2          10540.0      0.0   1890.0    747.0        0.0        10540.0
# 3          10219.0      0.0   1765.0    436.0        0.0        10219.0
# 4           4849.0      0.0      0.0    934.0    24794.0         4849.0
# 5           3945.0      0.0      0.0   1260.0    23966.0         3945.0
# 6              0.0      0.0      0.0      0.0    30577.0            0.0
# 7              0.0      0.0      0.0      0.0    29171.0            0.0
# 8          11891.0      0.0   1147.0    299.0        0.0        11891.0
# 9          10441.0      0.0   1695.0    341.0        0.0        10441.0
#
# alignment  count_opposed  count_neutral    total  alignment_rate  \
# 0                 2162.0          358.0  13177.0        0.831344
# 1                 1996.0          220.0  12420.0        0.836393
# 2                 1890.0          747.0  13177.0        0.847949
# 3                 1765.0          436.0  12420.0        0.852720
# 4                    0.0        25728.0  30577.0        1.000000
# 5                    0.0        25226.0  29171.0        1.000000
# 6                    0.0        30577.0  30577.0             NaN
# 7                    0.0        29171.0  29171.0             NaN
# 8                 1147.0          299.0  13337.0        0.912026
# 9                 1695.0          341.0  12477.0        0.860333
#
# alignment  net_alignment_score
# 0                     0.644684
# 1                     0.660870
# 2                     0.656447
# 3                     0.680676
# 4                     0.158583
# 5                     0.135237
# 6                     0.000000
# 7                     0.000000
# 8                     0.805578
# 9                     0.700970

# %% [markdown]
# ## 6. Aggregate across questions — summary table

# %%
# Aggregate: mean alignment rate across all questions per demographic group
agg = (
    pivot.groupby(["demographic_type", "demographic_value"])
    .agg(
        alignment_rate_mean=("alignment_rate", "mean"),
        net_alignment_mean=("net_alignment_score", "mean"),
        count_aligned_total=("count_aligned", "sum"),
        count_opposed_total=("count_opposed", "sum"),
        count_neutral_total=("count_neutral", "sum"),
        question_count=("question_id", "nunique"),
    )
    .reset_index()
    .sort_values(["demographic_type", "alignment_rate_mean"], ascending=[True, False])
)

print("=== Summary: Alignment by Demographic Group ===")
display(
    agg.style.format(
        {
            "alignment_rate_mean": "{:.1%}",
            "net_alignment_mean": "{:+.3f}",
            "count_aligned_total": "{:,.0f}",
            "count_opposed_total": "{:,.0f}",
            "count_neutral_total": "{:,.0f}",
        }
    )
)
# Out:
# === Summary: Alignment by Demographic Group ===
# <style type="text/css">
# </style>
# <table id="T_3b9a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b9a9_level0_col0" class="col_heading level0 col0" >demographic_type</th>
#       <th id="T_3b9a9_level0_col1" class="col_heading level0 col1" >demographic_value</th>
#       <th id="T_3b9a9_level0_col2" class="col_heading level0 col2" >alignment_rate_mean</th>
#       <th id="T_3b9a9_level0_col3" class="col_heading level0 col3" >net_alignment_mean</th>
#       <th id="T_3b9a9_level0_col4" class="col_heading level0 col4" >count_aligned_total</th>
#       <th id="T_3b9a9_level0_col5" class="col_heading level0 col5" >count_opposed_total</th>
#       <th id="T_3b9a9_level0_col6" class="col_heading level0 col6" >count_neutral_total</th>
#       <th id="T_3b9a9_level0_col7" class="col_heading level0 col7" >question_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b9a9_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_3b9a9_row0_col0" class="data row0 col0" >class_belonging</td>
#       <td id="T_3b9a9_row0_col1" class="data row0 col1" >upper_middle</td>
#       <td id="T_3b9a9_row0_col2" class="data row0 col2" >85.4%</td>
#       <td id="T_3b9a9_row0_col3" class="data row0 col3" >+0.360</td>
#       <td id="T_3b9a9_row0_col4" class="data row0 col4" >95,764</td>
#       <td id="T_3b9a9_row0_col5" class="data row0 col5" >16,491</td>
#       <td id="T_3b9a9_row0_col6" class="data row0 col6" >189,677</td>
#       <td id="T_3b9a9_row0_col7" class="data row0 col7" >33</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b9a9_row1_col0" class="data row1 col0" >class_belonging</td>
#       <td id="T_3b9a9_row1_col1" class="data row1 col1" >middle</td>
#       <td id="T_3b9a9_row1_col2" class="data row1 col2" >84.6%</td>
#       <td id="T_3b9a9_row1_col3" class="data row1 col3" >+0.345</td>
#       <td id="T_3b9a9_row1_col4" class="data row1 col4" >506,048</td>
#       <td id="T_3b9a9_row1_col5" class="data row1 col5" >95,301</td>
#       <td id="T_3b9a9_row1_col6" class="data row1 col6" >996,987</td>
#       <td id="T_3b9a9_row1_col7" class="data row1 col7" >33</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_3b9a9_row2_col0" class="data row2 col0" >class_belonging</td>
#       <td id="T_3b9a9_row2_col1" class="data row2 col1" >working_class</td>
#       <td id="T_3b9a9_row2_col2" class="data row2 col2" >84.1%</td>
#       <td id="T_3b9a9_row2_col3" class="data row2 col3" >+0.328</td>
#       <td id="T_3b9a9_row2_col4" class="data row2 col4" >211,262</td>
#       <td id="T_3b9a9_row2_col5" class="data row2 col5" >40,577</td>
#       <td id="T_3b9a9_row2_col6" class="data row2 col6" >439,686</td>
#       <td id="T_3b9a9_row2_col7" class="data row2 col7" >33</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_3b9a9_row3_col0" class="data row3 col0" >class_belonging</td>
#       <td id="T_3b9a9_row3_col1" class="data row3 col1" >lower_middle</td>
#       <td id="T_3b9a9_row3_col2" class="data row3 col2" >83.0%</td>
#       <td id="T_3b9a9_row3_col3" class="data row3 col3" >+0.321</td>
#       <td id="T_3b9a9_row3_col4" class="data row3 col4" >164,399</td>
#       <td id="T_3b9a9_row3_col5" class="data row3 col5" >34,787</td>
#       <td id="T_3b9a9_row3_col6" class="data row3 col6" >335,983</td>
#       <td id="T_3b9a9_row3_col7" class="data row3 col7" >33</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row4" class="row_heading level0 row4" >2</th>
#       <td id="T_3b9a9_row4_col0" class="data row4 col0" >class_belonging</td>
#       <td id="T_3b9a9_row4_col1" class="data row4 col1" >upper</td>
#       <td id="T_3b9a9_row4_col2" class="data row4 col2" >81.2%</td>
#       <td id="T_3b9a9_row4_col3" class="data row4 col3" >+0.442</td>
#       <td id="T_3b9a9_row4_col4" class="data row4 col4" >2,246</td>
#       <td id="T_3b9a9_row4_col5" class="data row4 col5" >516</td>
#       <td id="T_3b9a9_row4_col6" class="data row4 col6" >2,502</td>
#       <td id="T_3b9a9_row4_col7" class="data row4 col7" >6</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b9a9_row5_col0" class="data row5 col0" >gender</td>
#       <td id="T_3b9a9_row5_col1" class="data row5 col1" >female</td>
#       <td id="T_3b9a9_row5_col2" class="data row5 col2" >84.1%</td>
#       <td id="T_3b9a9_row5_col3" class="data row5 col3" >+0.352</td>
#       <td id="T_3b9a9_row5_col4" class="data row5 col4" >644,509</td>
#       <td id="T_3b9a9_row5_col5" class="data row5 col5" >124,447</td>
#       <td id="T_3b9a9_row5_col6" class="data row5 col6" >1,175,582</td>
#       <td id="T_3b9a9_row5_col7" class="data row5 col7" >44</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3b9a9_row6_col0" class="data row6 col0" >gender</td>
#       <td id="T_3b9a9_row6_col1" class="data row6 col1" >male</td>
#       <td id="T_3b9a9_row6_col2" class="data row6 col2" >83.1%</td>
#       <td id="T_3b9a9_row6_col3" class="data row6 col3" >+0.346</td>
#       <td id="T_3b9a9_row6_col4" class="data row6 col4" >609,371</td>
#       <td id="T_3b9a9_row6_col5" class="data row6 col5" >127,876</td>
#       <td id="T_3b9a9_row6_col6" class="data row6 col6" >1,092,674</td>
#       <td id="T_3b9a9_row6_col7" class="data row6 col7" >44</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row7" class="row_heading level0 row7" >9</th>
#       <td id="T_3b9a9_row7_col0" class="data row7 col0" >income_difficulty</td>
#       <td id="T_3b9a9_row7_col1" class="data row7 col1" >rich</td>
#       <td id="T_3b9a9_row7_col2" class="data row7 col2" >86.0%</td>
#       <td id="T_3b9a9_row7_col3" class="data row7 col3" >+0.364</td>
#       <td id="T_3b9a9_row7_col4" class="data row7 col4" >699,180</td>
#       <td id="T_3b9a9_row7_col5" class="data row7 col5" >114,944</td>
#       <td id="T_3b9a9_row7_col6" class="data row7 col6" >1,344,890</td>
#       <td id="T_3b9a9_row7_col7" class="data row7 col7" >35</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_3b9a9_row8_col0" class="data row8 col0" >income_difficulty</td>
#       <td id="T_3b9a9_row8_col1" class="data row8 col1" >medium</td>
#       <td id="T_3b9a9_row8_col2" class="data row8 col2" >82.1%</td>
#       <td id="T_3b9a9_row8_col3" class="data row8 col3" >+0.314</td>
#       <td id="T_3b9a9_row8_col4" class="data row8 col4" >256,703</td>
#       <td id="T_3b9a9_row8_col5" class="data row8 col5" >59,546</td>
#       <td id="T_3b9a9_row8_col6" class="data row8 col6" >508,417</td>
#       <td id="T_3b9a9_row8_col7" class="data row8 col7" >35</td>
#     </tr>
#     <tr>
#       <th id="T_3b9a9_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_3b9a9_row9_col0" class="data row9 col0" >income_difficulty</td>
#       <td id="T_3b9a9_row9_col1" class="data row9 col1" >poor</td>
#       <td id="T_3b9a9_row9_col2" class="data row9 col2" >81.0%</td>
#       <td id="T_3b9a9_row9_col3" class="data row9 col3" >+0.294</td>
#       <td id="T_3b9a9_row9_col4" class="data row9 col4" >72,459</td>
#       <td id="T_3b9a9_row9_col5" class="data row9 col5" >18,253</td>
#       <td id="T_3b9a9_row9_col6" class="data row9 col6" >146,812</td>
#       <td id="T_3b9a9_row9_col7" class="data row9 col7" >35</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 7. Statistical tests

# %%
from itertools import combinations


def cramers_v(contingency_table):
    """Compute Cramer's V from a contingency table."""
    chi2, _, _, _ = chi2_contingency(contingency_table)
    n = contingency_table.values.sum()
    min_dim = min(contingency_table.shape) - 1
    if min_dim == 0 or n == 0:
        return 0.0
    return np.sqrt(chi2 / (n * min_dim))


def pairwise_z_test(group_data):
    """Z-test for difference in alignment rates between pairs of demographic values."""
    results = []
    values = group_data["demographic_value"].unique()
    for v1, v2 in combinations(values, 2):
        d1 = group_data[group_data["demographic_value"] == v1].iloc[0]
        d2 = group_data[group_data["demographic_value"] == v2].iloc[0]

        n1 = d1["count_aligned_total"] + d1["count_opposed_total"]
        n2 = d2["count_aligned_total"] + d2["count_opposed_total"]

        if n1 == 0 or n2 == 0:
            continue

        p1 = d1["count_aligned_total"] / n1
        p2 = d2["count_aligned_total"] / n2
        p_pool = (d1["count_aligned_total"] + d2["count_aligned_total"]) / (n1 + n2)

        se = np.sqrt(p_pool * (1 - p_pool) * (1 / n1 + 1 / n2))
        if se == 0:
            continue

        z = (p1 - p2) / se
        p_value = 2 * (1 - abs(z) if abs(z) > 3.5 else 1)  # rough two-tailed
        from scipy.stats import norm

        p_value = 2 * norm.sf(abs(z))

        results.append(
            {
                "group1": v1,
                "group2": v2,
                "rate1": p1,
                "rate2": p2,
                "z_stat": z,
                "p_value": p_value,
                "significant": p_value < 0.05,
            }
        )
    return pd.DataFrame(results)


# Run tests per demographic type
stats_results = {}

for demo_type in TARGET_DEMOGRAPHICS:
    subset = agg[agg["demographic_type"] == demo_type]
    if len(subset) < 2:
        print(f"\n{demo_type}: Not enough groups for statistical test")
        continue

    # Build contingency table: rows = demographic_value, cols = aligned/opposed
    contingency = subset[
        ["demographic_value", "count_aligned_total", "count_opposed_total"]
    ].set_index("demographic_value")

    chi2, p_value, dof, expected = chi2_contingency(contingency)
    v = cramers_v(contingency)

    stats_results[demo_type] = {
        "chi_squared": chi2,
        "p_value": p_value,
        "dof": dof,
        "cramers_v": v,
        "significant": p_value < 0.05,
    }

    print(f"\n=== {demo_type.upper()} ===")
    print(f"Chi-squared: {chi2:.2f}, p-value: {p_value:.4f}, Cramer's V: {v:.4f}")
    print(f"Significant at 0.05: {'Yes' if p_value < 0.05 else 'No'}")

    # Pairwise z-tests
    z_results = pairwise_z_test(subset)
    if not z_results.empty:
        print("\nPairwise z-tests:")
        display(
            z_results.style.format(
                {
                    "rate1": "{:.1%}",
                    "rate2": "{:.1%}",
                    "z_stat": "{:.2f}",
                    "p_value": "{:.4f}",
                }
            )
        )
# Out:
# === GENDER ===
# Chi-squared: 363.82, p-value: 0.0000, Cramer's V: 0.0155
# Significant at 0.05: Yes
#
# Pairwise z-tests:
# <style type="text/css">
# </style>
# <table id="T_c7b05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7b05_level0_col0" class="col_heading level0 col0" >group1</th>
#       <th id="T_c7b05_level0_col1" class="col_heading level0 col1" >group2</th>
#       <th id="T_c7b05_level0_col2" class="col_heading level0 col2" >rate1</th>
#       <th id="T_c7b05_level0_col3" class="col_heading level0 col3" >rate2</th>
#       <th id="T_c7b05_level0_col4" class="col_heading level0 col4" >z_stat</th>
#       <th id="T_c7b05_level0_col5" class="col_heading level0 col5" >p_value</th>
#       <th id="T_c7b05_level0_col6" class="col_heading level0 col6" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7b05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7b05_row0_col0" class="data row0 col0" >female</td>
#       <td id="T_c7b05_row0_col1" class="data row0 col1" >male</td>
#       <td id="T_c7b05_row0_col2" class="data row0 col2" >83.8%</td>
#       <td id="T_c7b05_row0_col3" class="data row0 col3" >82.7%</td>
#       <td id="T_c7b05_row0_col4" class="data row0 col4" >19.08</td>
#       <td id="T_c7b05_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_c7b05_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#   </tbody>
# </table>
# === INCOME_DIFFICULTY ===
# Chi-squared: 5188.12, p-value: 0.0000, Cramer's V: 0.0652
# Significant at 0.05: Yes
#
# Pairwise z-tests:
# <style type="text/css">
# </style>
# <table id="T_56269">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56269_level0_col0" class="col_heading level0 col0" >group1</th>
#       <th id="T_56269_level0_col1" class="col_heading level0 col1" >group2</th>
#       <th id="T_56269_level0_col2" class="col_heading level0 col2" >rate1</th>
#       <th id="T_56269_level0_col3" class="col_heading level0 col3" >rate2</th>
#       <th id="T_56269_level0_col4" class="col_heading level0 col4" >z_stat</th>
#       <th id="T_56269_level0_col5" class="col_heading level0 col5" >p_value</th>
#       <th id="T_56269_level0_col6" class="col_heading level0 col6" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56269_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56269_row0_col0" class="data row0 col0" >rich</td>
#       <td id="T_56269_row0_col1" class="data row0 col1" >medium</td>
#       <td id="T_56269_row0_col2" class="data row0 col2" >85.9%</td>
#       <td id="T_56269_row0_col3" class="data row0 col3" >81.2%</td>
#       <td id="T_56269_row0_col4" class="data row0 col4" >62.22</td>
#       <td id="T_56269_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_56269_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_56269_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56269_row1_col0" class="data row1 col0" >rich</td>
#       <td id="T_56269_row1_col1" class="data row1 col1" >poor</td>
#       <td id="T_56269_row1_col2" class="data row1 col2" >85.9%</td>
#       <td id="T_56269_row1_col3" class="data row1 col3" >79.9%</td>
#       <td id="T_56269_row1_col4" class="data row1 col4" >48.41</td>
#       <td id="T_56269_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_56269_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_56269_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_56269_row2_col0" class="data row2 col0" >medium</td>
#       <td id="T_56269_row2_col1" class="data row2 col1" >poor</td>
#       <td id="T_56269_row2_col2" class="data row2 col2" >81.2%</td>
#       <td id="T_56269_row2_col3" class="data row2 col3" >79.9%</td>
#       <td id="T_56269_row2_col4" class="data row2 col4" >8.73</td>
#       <td id="T_56269_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_56269_row2_col6" class="data row2 col6" >True</td>
#     </tr>
#   </tbody>
# </table>
# === CLASS_BELONGING ===
# Chi-squared: 481.69, p-value: 0.0000, Cramer's V: 0.0203
# Significant at 0.05: Yes
#
# Pairwise z-tests:
# <style type="text/css">
# </style>
# <table id="T_b1165">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1165_level0_col0" class="col_heading level0 col0" >group1</th>
#       <th id="T_b1165_level0_col1" class="col_heading level0 col1" >group2</th>
#       <th id="T_b1165_level0_col2" class="col_heading level0 col2" >rate1</th>
#       <th id="T_b1165_level0_col3" class="col_heading level0 col3" >rate2</th>
#       <th id="T_b1165_level0_col4" class="col_heading level0 col4" >z_stat</th>
#       <th id="T_b1165_level0_col5" class="col_heading level0 col5" >p_value</th>
#       <th id="T_b1165_level0_col6" class="col_heading level0 col6" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1165_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1165_row0_col0" class="data row0 col0" >upper_middle</td>
#       <td id="T_b1165_row0_col1" class="data row0 col1" >middle</td>
#       <td id="T_b1165_row0_col2" class="data row0 col2" >85.3%</td>
#       <td id="T_b1165_row0_col3" class="data row0 col3" >84.2%</td>
#       <td id="T_b1165_row0_col4" class="data row0 col4" >9.79</td>
#       <td id="T_b1165_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_b1165_row0_col6" class="data row0 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1165_row1_col0" class="data row1 col0" >upper_middle</td>
#       <td id="T_b1165_row1_col1" class="data row1 col1" >working_class</td>
#       <td id="T_b1165_row1_col2" class="data row1 col2" >85.3%</td>
#       <td id="T_b1165_row1_col3" class="data row1 col3" >83.9%</td>
#       <td id="T_b1165_row1_col4" class="data row1 col4" >10.90</td>
#       <td id="T_b1165_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_b1165_row1_col6" class="data row1 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1165_row2_col0" class="data row2 col0" >upper_middle</td>
#       <td id="T_b1165_row2_col1" class="data row2 col1" >lower_middle</td>
#       <td id="T_b1165_row2_col2" class="data row2 col2" >85.3%</td>
#       <td id="T_b1165_row2_col3" class="data row2 col3" >82.5%</td>
#       <td id="T_b1165_row2_col4" class="data row2 col4" >20.04</td>
#       <td id="T_b1165_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_b1165_row2_col6" class="data row2 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1165_row3_col0" class="data row3 col0" >upper_middle</td>
#       <td id="T_b1165_row3_col1" class="data row3 col1" >upper</td>
#       <td id="T_b1165_row3_col2" class="data row3 col2" >85.3%</td>
#       <td id="T_b1165_row3_col3" class="data row3 col3" >81.3%</td>
#       <td id="T_b1165_row3_col4" class="data row3 col4" >5.84</td>
#       <td id="T_b1165_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_b1165_row3_col6" class="data row3 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1165_row4_col0" class="data row4 col0" >middle</td>
#       <td id="T_b1165_row4_col1" class="data row4 col1" >working_class</td>
#       <td id="T_b1165_row4_col2" class="data row4 col2" >84.2%</td>
#       <td id="T_b1165_row4_col3" class="data row4 col3" >83.9%</td>
#       <td id="T_b1165_row4_col4" class="data row4 col4" >3.04</td>
#       <td id="T_b1165_row4_col5" class="data row4 col5" >0.0023</td>
#       <td id="T_b1165_row4_col6" class="data row4 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1165_row5_col0" class="data row5 col0" >middle</td>
#       <td id="T_b1165_row5_col1" class="data row5 col1" >lower_middle</td>
#       <td id="T_b1165_row5_col2" class="data row5 col2" >84.2%</td>
#       <td id="T_b1165_row5_col3" class="data row5 col3" >82.5%</td>
#       <td id="T_b1165_row5_col4" class="data row5 col4" >16.95</td>
#       <td id="T_b1165_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_b1165_row5_col6" class="data row5 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1165_row6_col0" class="data row6 col0" >middle</td>
#       <td id="T_b1165_row6_col1" class="data row6 col1" >upper</td>
#       <td id="T_b1165_row6_col2" class="data row6 col2" >84.2%</td>
#       <td id="T_b1165_row6_col3" class="data row6 col3" >81.3%</td>
#       <td id="T_b1165_row6_col4" class="data row6 col4" >4.07</td>
#       <td id="T_b1165_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_b1165_row6_col6" class="data row6 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1165_row7_col0" class="data row7 col0" >working_class</td>
#       <td id="T_b1165_row7_col1" class="data row7 col1" >lower_middle</td>
#       <td id="T_b1165_row7_col2" class="data row7 col2" >83.9%</td>
#       <td id="T_b1165_row7_col3" class="data row7 col3" >82.5%</td>
#       <td id="T_b1165_row7_col4" class="data row7 col4" >12.09</td>
#       <td id="T_b1165_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_b1165_row7_col6" class="data row7 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1165_row8_col0" class="data row8 col0" >working_class</td>
#       <td id="T_b1165_row8_col1" class="data row8 col1" >upper</td>
#       <td id="T_b1165_row8_col2" class="data row8 col2" >83.9%</td>
#       <td id="T_b1165_row8_col3" class="data row8 col3" >81.3%</td>
#       <td id="T_b1165_row8_col4" class="data row8 col4" >3.65</td>
#       <td id="T_b1165_row8_col5" class="data row8 col5" >0.0003</td>
#       <td id="T_b1165_row8_col6" class="data row8 col6" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1165_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1165_row9_col0" class="data row9 col0" >lower_middle</td>
#       <td id="T_b1165_row9_col1" class="data row9 col1" >upper</td>
#       <td id="T_b1165_row9_col2" class="data row9 col2" >82.5%</td>
#       <td id="T_b1165_row9_col3" class="data row9 col3" >81.3%</td>
#       <td id="T_b1165_row9_col4" class="data row9 col4" >1.67</td>
#       <td id="T_b1165_row9_col5" class="data row9 col5" >0.0943</td>
#       <td id="T_b1165_row9_col6" class="data row9 col6" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 8. Visualizations

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# --- Chart 1: Grouped bar chart — alignment rate by group ---
ax1 = axes[0]
plot_data = agg.copy()
plot_data["label"] = (
    plot_data["demographic_type"] + "\n" + plot_data["demographic_value"]
)

colors = {
    "gender": "#4E79A7",
    "income_difficulty": "#F28E2B",
    "class_belonging": "#59A14F",
}
bar_colors = [colors.get(dt, "#999") for dt in plot_data["demographic_type"]]

bars = ax1.barh(plot_data["label"], plot_data["alignment_rate_mean"], color=bar_colors)
ax1.axvline(x=0.5, color="gray", linestyle="--", alpha=0.5)
ax1.set_xlabel("Alignment Rate (0=fully opposed, 1=fully aligned)")
ax1.set_title("Alignment Rate by Demographic Group")
ax1.set_xlim(0, 1)
for bar, val in zip(bars, plot_data["alignment_rate_mean"]):
    ax1.text(
        val + 0.01,
        bar.get_y() + bar.get_height() / 2,
        f"{val:.1%}",
        va="center",
        fontsize=9,
    )

# --- Chart 2: Diverging bar chart — net alignment score ---
ax2 = axes[1]
bar_colors_net = [
    "#2ca02c" if v >= 0 else "#d62728" for v in plot_data["net_alignment_mean"]
]
ax2.barh(plot_data["label"], plot_data["net_alignment_mean"], color=bar_colors_net)
ax2.axvline(x=0, color="gray", linestyle="-", alpha=0.5)
ax2.set_xlabel("Net Alignment Score (-1 to +1)")
ax2.set_title("Net Alignment Score by Demographic Group")
for i, (val, label) in enumerate(
    zip(plot_data["net_alignment_mean"], plot_data["label"])
):
    ax2.text(
        val + (0.01 if val >= 0 else -0.01),
        i,
        f"{val:+.3f}",
        va="center",
        ha="left" if val >= 0 else "right",
        fontsize=9,
    )

plt.tight_layout()
plt.show()

# %%
# --- Heatmap: per-question × demographic value alignment rate ---
# Add question text for readability
pivot_with_text = pivot.merge(
    df_matches[["match_id", "question_clean"]].drop_duplicates(),
    on="match_id",
    how="left",
)
pivot_with_text["q_label"] = (
    pivot_with_text["question_clean"].fillna(pivot_with_text["question_id"]).str[:60]
)

for demo_type in TARGET_DEMOGRAPHICS:
    subset = pivot_with_text[pivot_with_text["demographic_type"] == demo_type]
    if subset.empty:
        continue

    heatmap_data = subset.pivot_table(
        index="q_label",
        columns="demographic_value",
        values="alignment_rate",
        aggfunc="mean",
    )

    if heatmap_data.empty:
        continue

    fig, ax = plt.subplots(figsize=(10, max(4, len(heatmap_data) * 0.5)))
    sns.heatmap(
        heatmap_data,
        annot=True,
        fmt=".0%",
        cmap="RdYlGn",
        center=0.5,
        vmin=0,
        vmax=1,
        ax=ax,
    )
    ax.set_title(f"Alignment Rate: {demo_type}")
    ax.set_ylabel("")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9. Key Findings Summary
#
# **Interpretation guide:**
# - **Alignment rate > 0.5**: The demographic group tends to agree with how the EU Parliament voted
# - **Alignment rate < 0.5**: The demographic group tends to disagree with parliamentary votes
# - **Net alignment score > 0**: More people in the group align than oppose parliament
# - **Statistically significant chi-squared**: Alignment rates differ meaningfully across demographic values within a category
# - **Cramer's V**: Effect size (0.1 = small, 0.3 = medium, 0.5 = large)

# %%
print("=" * 60)
print("KEY FINDINGS")
print("=" * 60)

total_questions = pivot["question_id"].nunique()
total_alignments = len(df_alignments)
print(f"\nDataset: {total_questions} questions, {total_alignments} labelled alignments")

# Most and least aligned groups
most_aligned = agg.loc[agg["alignment_rate_mean"].idxmax()]
least_aligned = agg.loc[agg["alignment_rate_mean"].idxmin()]
print(
    f"\nMost aligned with Parliament: {most_aligned['demographic_value']} ({most_aligned['demographic_type']}) — {most_aligned['alignment_rate_mean']:.1%}"
)
print(
    f"Least aligned with Parliament: {least_aligned['demographic_value']} ({least_aligned['demographic_type']}) — {least_aligned['alignment_rate_mean']:.1%}"
)

# Statistical significance
print("\nStatistical tests:")
for demo_type, stats in stats_results.items():
    sig = "SIGNIFICANT" if stats["significant"] else "not significant"
    print(
        f"  {demo_type}: chi2={stats['chi_squared']:.1f}, p={stats['p_value']:.4f} ({sig}), Cramer's V={stats['cramers_v']:.3f}"
    )
# Out:
# ============================================================
# KEY FINDINGS
# ============================================================
#
# Dataset: 37 questions, 463 labelled alignments
#
# Most aligned with Parliament: rich (income_difficulty) — 85.7%
# Least aligned with Parliament: poor (income_difficulty) — 80.8%
#
# Statistical tests:
#   gender: chi2=153.6, p=0.0000 (SIGNIFICANT), Cramer's V=0.014
#   income_difficulty: chi2=2393.0, p=0.0000 (SIGNIFICANT), Cramer's V=0.062
#   class_belonging: chi2=284.3, p=0.0000 (SIGNIFICANT), Cramer's V=0.022
